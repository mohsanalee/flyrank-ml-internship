# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohsanalee/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **My lane: Content refresh / editorial prioritization**
#
# I chose the content refresh lane because I want to help editors decide which content pages should be reviewed first. The goal is to use available content and performance signals to prioritize pages that may need attention, instead of treating every page equally. This is useful because an editor has limited time and needs a practical way to decide where to start.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which content pages should an editor review and potentially refresh first?
#
# **Action:** An editor uses the priority ranking to choose which pages to inspect, update, or improve.
#
# **Cost of a wrong call:** If a page is ranked too highly, the editor may waste time reviewing content that does not need immediate attention. If an important declining page is ranked too low, the editor may miss an opportunity to refresh it.
#
# **Research question:** Can content and recent performance signals be used to rank pages by their likelihood of needing attention, so editors can focus their limited time on the highest-priority pages?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
from pathlib import Path
import pandas as pd

# Find the starter dataset from the repo root or notebook folder.
candidates = [
    Path("data/raw/content_refresh_anonymized.csv"),
    Path("../../data/raw/content_refresh_anonymized.csv"),
]

data_path = next((p for p in candidates if p.exists()), None)

if data_path is None:
    raise FileNotFoundError("Could not find content_refresh_anonymized.csv")

df = pd.read_csv(data_path)

print("Dataset shape:", df.shape)
print("Number of content items:", len(df))
print("Content types:")
print(df["content_type"].value_counts())

print("\nDeclining label distribution:")
print(df["is_declining_label"].value_counts(dropna=False))

print("\nAverage impressions:", round(df["impressions_90d"].mean(), 2))
print("Average clicks:", round(df["clicks_90d"].mean(), 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 # This cell is for CODE (numbers, a query, a check).
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#       3 from pathlib import Path
# ----> 4 import pandas as pd
#       6 # Find the starter dataset from the repo root or notebook folder.
#       7 candidates = [
#       8     Path("data/raw/content_refresh_anonymized.csv"),
#       9     Path("../../data/raw/content_refresh_anonymized.csv"),
#      10 ]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### What I can claim
#
# I can use the available data to measure relationships between content/performance signals and observed outcomes. The eventual model or ranking can provide decision-support for editors by helping prioritize which pages to review first.
#
# ### What I cannot claim
#
# I cannot claim that the model will cause traffic or rankings to improve, or that it can predict Google's future ranking decisions. I also should not claim that a page definitely needs a refresh just because it receives a high priority score. The result should be treated as a measured, decision-support signal that an editor can investigate.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
